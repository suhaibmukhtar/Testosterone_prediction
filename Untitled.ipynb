# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## Load the data

# %%
data=pd.read_excel('ptestost.xlsx')

# %%
data.shape
# Out:
# (3397, 7)

# %% [markdown]
# ### Instead of WC, AC is given name to column

# %% [markdown]
# ## Changing the name of columns

# %%
data.columns
# Out:
# Index(['Age', 'DM', 'TG', 'HT', 'HDL', 'AC', 'T'], dtype='object')

# %%
data.columns=['AGE','Diabitic',"TG",'Hyper_Tension','High_Density_Lipoprotein','Waist_Circumfrence','Target']

# %%
data.head()
# Out:
#    AGE  Diabitic   TG  Hyper_Tension  High_Density_Lipoprotein  \
# 0   60         0  145              1                      35.0
# 1   75         0   93              0                      48.0
# 2   50         0  151              0                      57.0
# 3   62         0  178              1                      28.0
# 4   55         0  138              1                      62.0
#
#    Waist_Circumfrence  Target
# 0               114.0       0
# 1                84.0       0
# 2                99.0       0
# 3               109.0       0
# 4                98.0       0

# %% [markdown]
# ### How data Looks like

# %%
data.sample(5)
# Out:
#       AGE  Diabitic   TG  Hyper_Tension  High_Density_Lipoprotein  \
# 60     54         0   58              0                      49.0
# 444    71         0   53              0                      48.0
# 1374   49         0   73              0                      62.0
# 2821   69         1  267              1                      57.0
# 407    60         0   73              0                      67.0
#
#       Waist_Circumfrence  Target
# 60                  78.0       0
# 444                 98.0       0
# 1374                90.0       0
# 2821                99.0       1
# 407                101.0       0

# %% [markdown]
# ## Distribution of categories in target column

# %%
data['Target'].value_counts()
# Out:
# 0    2741
# 1     656
# Name: Target, dtype: int64

# %%
sns.countplot(x=data['Target'],data=data)
# Out:
# <AxesSubplot:xlabel='Target', ylabel='count'>

# %% [markdown]
# ## Pie chart

# %%
explode=[0.1,0]
data['Target'].value_counts().plot(kind='pie',autopct="%.2f%%",explode=explode)
plt.show()

# %% [markdown]
# ## Size, null values and data type of each column

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3397 entries, 0 to 3396
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   AGE                       3397 non-null   int64
#  1   Diabitic                  3397 non-null   int64
#  2   TG                        3397 non-null   int64
#  3   Hyper_Tension             3397 non-null   int64
#  4   High_Density_Lipoprotein  3397 non-null   float64
#  5   Waist_Circumfrence        3397 non-null   float64
#  6   Target                    3397 non-null   int64
# dtypes: float64(2), int64(5)
# memory usage: 185.9 KB

# %% [markdown]
# ## How Big is data

# %%
data.shape
# Out:
# (3397, 7)

# %% [markdown]
# ## Check for missing values

# %%
data.isnull().sum()
# Out:
# AGE                         0
# Diabitic                    0
# TG                          0
# Hyper_Tension               0
# High_Density_Lipoprotein    0
# Waist_Circumfrence          0
# Target                      0
# dtype: int64

# %% [markdown]
# ## Check for duplicate values

# %%
data.describe()
# Out:
#                AGE     Diabitic           TG  Hyper_Tension  \
# count  3397.000000  3397.000000  3397.000000    3397.000000
# mean     61.327348     0.388578   155.269650       0.511922
# std      10.072821     0.487499    88.840249       0.499931
# min      45.000000     0.000000    12.000000       0.000000
# 25%      53.000000     0.000000    97.000000       0.000000
# 50%      60.000000     0.000000   136.000000       1.000000
# 75%      69.000000     1.000000   183.000000       1.000000
# max      85.000000     1.000000   980.000000       1.000000
#
#        High_Density_Lipoprotein  Waist_Circumfrence       Target
# count               3397.000000         3397.000000  3397.000000
# mean                  46.325493           98.916515     0.193112
# std                   10.960146           10.629471     0.394798
# min                   13.000000           43.000000     0.000000
# 25%                   39.000000           92.000000     0.000000
# 50%                   45.000000           98.000000     0.000000
# 75%                   52.000000          105.000000     0.000000
# max                  116.000000          198.000000     1.000000

# %% [markdown]
# ## Distribution of diabities column

# %%
data['Diabitic'].value_counts().plot(kind="pie",autopct="%.2f%%",explode=[0,0.1])
plt.show()

# %% [markdown]
# ## Hyper-Tension

# %%
data['Hyper_Tension'].value_counts().plot(kind='pie',autopct='%.2f%%',explode=[0.1,0])
plt.show()

# %%
plt.hist(data['High_Density_Lipoprotein'],bins=20)
plt.show()

# %%
sns.displot(data['High_Density_Lipoprotein'],kde=True)

# %%
sns.displot(data['Waist_Circumfrence'],kde=True)

# %% [markdown]
# ## How is correlation b/w columns

# %%
data.corr()
# Out:
#                                AGE  Diabitic        TG  Hyper_Tension  \
# AGE                       1.000000  0.092162 -0.159567       0.284759
# Diabitic                  0.092162  1.000000  0.130495       0.170677
# TG                       -0.159567  0.130495  1.000000       0.053504
# Hyper_Tension             0.284759  0.170677  0.053504       1.000000
# High_Density_Lipoprotein -0.022599 -0.064131 -0.305067      -0.083300
# Waist_Circumfrence       -0.019767  0.229361  0.227617       0.213183
# Target                    0.012755  0.134780  0.206086       0.107686
#
#                           High_Density_Lipoprotein  Waist_Circumfrence  \
# AGE                                      -0.022599           -0.019767
# Diabitic                                 -0.064131            0.229361
# TG                                       -0.305067            0.227617
# Hyper_Tension                            -0.083300            0.213183
# High_Density_Lipoprotein                  1.000000           -0.197804
# Waist_Circumfrence                       -0.197804            1.000000
# Target                                   -0.109804            0.303493
#
#                             Target
# AGE                       0.012755
# Diabitic                  0.134780
# TG                        0.206086
# Hyper_Tension             0.107686
# High_Density_Lipoprotein -0.109804
# Waist_Circumfrence        0.303493
# Target                    1.000000

# %%
data.drop(['AGE'],axis=1,inplace=True)

# %%
x=data.drop(['Target'],axis=1)
y=data['Target']

# %%
print(x.shape)
print(y.shape)
# Out:
# (3397, 5)
# (3397,)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,stratify=y,random_state=42)

# %% [markdown]
# ## Applying Scaling on data

# %%
sc=StandardScaler()
x_train_sc=sc.fit_transform(x_train)
x_test_sc=sc.transform(x_test)

# %%
x_train_sc.shape
# Out:
# (2547, 5)

# %%
x_test_sc.shape
# Out:
# (850, 5)

# %% [markdown]
# ## Results without Balancing

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()

# %%
lr.fit(x_train_sc,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=lr.predict(x_test_sc)

# %%
from sklearn.metrics import confusion_matrix,classification_report

# %%
cm=confusion_matrix(y_test,y_pred)

# %%
print(cm)
# Out:
# [[674  12]
#  [137  27]]

# %%
cr=classification_report(y_test,y_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.98      0.90       686
#            1       0.69      0.16      0.27       164
#
#     accuracy                           0.82       850
#    macro avg       0.76      0.57      0.58       850
# weighted avg       0.80      0.82      0.78       850

# %%
accuracy=lr.score(x_train_sc,y_train)
print("Accuracy:",accuracy)
# Out:
# Accuracy: 0.8131134668237142

# %%
accuracy=lr.score(x_test_sc,y_test)
print("Accuracy:",accuracy)
# Out:
# Accuracy: 0.8247058823529412

# %%
from sklearn import svm

# %%
sv=svm.SVC(kernel='linear')

# %%
sv.fit(x_train_sc,y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred=sv.predict(x_test_sc)

# %%
accuracy=sv.score(x_test_sc,y_test)
print("Accuracy:",accuracy)
# Out:
# Accuracy: 0.8070588235294117

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[686,   0],
#        [164,   0]], dtype=int64)

# %%
from sklearn.metrics import classification_report

# %%
cr=classification_report(y_test,y_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      1.00      0.89       686
#            1       0.00      0.00      0.00       164
#
#     accuracy                           0.81       850
#    macro avg       0.40      0.50      0.45       850
# weighted avg       0.65      0.81      0.72       850
# C:\Users\suhaib mukhtar\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\suhaib mukhtar\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\suhaib mukhtar\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# ## Applying smote

# %%
from imblearn.over_sampling import SMOTE

# %% [markdown]
# ## Distribution of data before applying smote

# %%
y_train.value_counts()
# Out:
# 0    2055
# 1     492
# Name: Target, dtype: int64

# %% [markdown]
# ## Distribution of data after applying smote

# %%
#note Smote is only applied to the training data not to the testing data
sm=SMOTE(random_state=42)
x_train_resampled,y_train_resampled=sm.fit_resample(x_train_sc,y_train)

# %%
y_train_resampled.value_counts()
# Out:
# 0    2055
# 1    2055
# Name: Target, dtype: int64

# %%
sns.countplot(x=y_train_resampled,data=data)
plt.show()

# %%
print(x_train_resampled.shape)
print(y_train_resampled.shape)
# Out:
# (4110, 6)
# (4110,)

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()

# %%
lr.fit(x_train_resampled,y_train_resampled)
# Out:
# LogisticRegression()

# %%
y_pred=lr.predict(x_test_sc)

# %%
from sklearn.metrics import confusion_matrix,classification_report

# %%
cm=confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[486, 200],
#        [ 39, 125]], dtype=int64)

# %%
cr=classification_report(y_test,y_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.71      0.80       686
#            1       0.38      0.76      0.51       164
#
#     accuracy                           0.72       850
#    macro avg       0.66      0.74      0.66       850
# weighted avg       0.82      0.72      0.75       850

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf=RandomForestClassifier(n_estimators=10,max_samples=0.7,random_state=42)
rf.fit(x_train_resampled,y_train_resampled)
# Out:
# RandomForestClassifier(max_samples=0.7, n_estimators=10, random_state=42)

# %%
yp=rf.predict(x_test_sc)

# %%
from sklearn.metrics import accuracy_score

# Assuming 'predictions' contains the predictions made by your model and 'y_test' contains the actual labels
accuracy = accuracy_score(y_test, yp)

print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.7705882352941177

# %%
cr=classification_report(y_test,yp)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.86      0.86       686
#            1       0.41      0.41      0.41       164
#
#     accuracy                           0.77       850
#    macro avg       0.63      0.63      0.63       850
# weighted avg       0.77      0.77      0.77       850

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors=10)

# Fit the classifier to the training data
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=10)

# %%
# Predict the labels for the test set
y_pred = knn.predict(x_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8188235294117647

# %%
import numpy as np
import pandas as pd
import xgboost as xgb
from sklearn.model_selection import StratifiedKFold, RandomizedSearchCV
from sklearn.metrics import accuracy_score, make_scorer
from imblearn.over_sampling import SMOTE

# Load the dataset
data=pd.read_excel('ptestost.xlsx')
df=data.copy()
# Split the dataset into features and target variable
X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values

# Resample the data to address class imbalance using SMOTE
sm = SMOTE(random_state=42)
X_resampled, y_resampled = sm.fit_resample(X, y)

# Create the stratified 10-fold cross-validator
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

# Define the hyperparameter grid for the XGBoost model
param_grid = {'max_depth': [3, 4, 5],
              'learning_rate': [0.05, 0.1, 0.15],
              'n_estimators': [100, 200, 300],
              'min_child_weight': [1, 3, 5],
              'gamma': [0, 0.1, 0.2]}

# Create the XGBoost classifier
xgb_classifier = xgb.XGBClassifier(objective='binary:logistic', random_state=42)

# Define the scoring metric for the randomized search
scoring_metric = make_scorer(accuracy_score)

# Create the randomized search object
random_search = RandomizedSearchCV(xgb_classifier, param_grid, n_iter=50, cv=skf, scoring=scoring_metric,
                                   random_state=42, verbose=1, n_jobs=-1)

# Fit the randomized search object to the resampled data
random_search.fit(X_resampled, y_resampled)

# Print the best hyperparameters and the associated mean cross-validation accuracy score
print(f"Best hyperparameters: {random_search.best_params_}")
print(f"Best mean cross-validation score: {random_search.best_score_:.4%}")

# Use the best model to make predictions on the test set
best_model = random_search.best_estimator_
predictions = best_model.predict(X_test)
accuracy = accuracy_score(y_test, predictions)
print(f"Test set accuracy: {accuracy:.4%}")
# Out:
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# Best hyperparameters: {'n_estimators': 200, 'min_child_weight': 1, 'max_depth': 5, 'learning_rate': 0.15, 'gamma': 0}
# Best mean cross-validation score: 87.2860%
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22860\1769426012.py in <module>
#      46 # Use the best model to make predictions on the test set
#      47 best_model = random_search.best_estimator_
# ---> 48 predictions = best_model.predict(X_test)
#      49 accuracy = accuracy_score(y_test, predictions)
#      50 print(f"Test set accuracy: {accuracy:.4%}")
#
# NameError: name 'X_test' is not defined

# %%
import numpy as np
import pandas as pd
import xgboost as xgb
from sklearn.model_selection import train_test_split, StratifiedKFold, RandomizedSearchCV
from sklearn.metrics import accuracy_score, make_scorer
from imblearn.over_sampling import SMOTE

# Load the dataset
df =data.copy()

# Split the dataset into features and target variable
X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values

# Resample the data to address class imbalance using SMOTE
sm = SMOTE(random_state=42)
X_resampled, y_resampled = sm.fit_resample(X, y)

# Split the resampled dataset into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.2, random_state=42)

# Create the stratified 10-fold cross-validator
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

# Define the hyperparameter grid for the XGBoost model
param_grid = {'max_depth': [3, 4, 5],
              'learning_rate': [0.05, 0.1, 0.15],
              'n_estimators': [100, 200, 300],
              'min_child_weight': [1, 3, 5],
              'gamma': [0, 0.1, 0.2]}

# Create the XGBoost classifier
xgb_classifier = xgb.XGBClassifier(objective='binary:logistic', random_state=42)

# Define the scoring metric for the randomized search
scoring_metric = make_scorer(accuracy_score)

# Create the randomized search object
random_search = RandomizedSearchCV(xgb_classifier, param_grid, n_iter=50, cv=skf, scoring=scoring_metric,
                                   random_state=42, verbose=1, n_jobs=-1)

# Fit the randomized search object to the training data
random_search.fit(X_train, y_train)

# Print the best hyperparameters and the associated mean cross-validation accuracy score
print(f"Best hyperparameters: {random_search.best_params_}")
print(f"Best mean cross-validation score: {random_search.best_score_:.2%}")

# Use the best model to make predictions on the test set
best_model = random_search.best_estimator_
predictions = best_model.predict(X_test)
accuracy = accuracy_score(y_test, predictions)
print(f"Test set accuracy: {accuracy:.2%}")
# Out:
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# Best hyperparameters: {'n_estimators': 300, 'min_child_weight': 1, 'max_depth': 5, 'learning_rate': 0.15, 'gamma': 0.1}
# Best mean cross-validation score: 85.95%
# Test set accuracy: 84.69%

# %%
import numpy as np
import pandas as pd
import xgboost as xgb
from sklearn.model_selection import StratifiedKFold, RandomizedSearchCV
from sklearn.metrics import accuracy_score, make_scorer
from imblearn.over_sampling import SMOTE

# Load the dataset
df = data.copy()

# Split the dataset into features and target variable
X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values

# Resample the data to address class imbalance using SMOTE
sm = SMOTE(random_state=42)
X_resampled, y_resampled = sm.fit_resample(X, y)

# Create the stratified 10-fold cross-validator
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

# Define the hyperparameter grid for the XGBoost model
param_grid = {'max_depth': [3, 4, 5],
              'learning_rate': [0.05, 0.1, 0.15],
              'n_estimators': [100, 200, 300],
              'min_child_weight': [1, 3, 5],
              'gamma': [0, 0.1, 0.2]}

# Create the XGBoost classifier
xgb_classifier = xgb.XGBClassifier(objective='binary:logistic', random_state=42)

# Define the scoring metric for the randomized search
scoring_metric = make_scorer(accuracy_score)

# Create the randomized search object
random_search = RandomizedSearchCV(xgb_classifier, param_grid, n_iter=50, cv=skf, scoring=scoring_metric,
                                   random_state=42, verbose=1, n_jobs=-1)

# Fit the randomized search object to the resampled data
random_search.fit(X_resampled, y_resampled)

# Print the best hyperparameters and the associated mean cross-validation accuracy score
print(f"Best hyperparameters: {random_search.best_params_}")
print(f"Best mean cross-validation score: {random_search.best_score_:.4%}")

# Use the best model to make predictions on the test set
best_model = random_search.best_estimator_
predictions = best_model.predict(X_test)
accuracy = accuracy_score(y_test, predictions)
print(f"Test set accuracy: {accuracy:.4%}")
# Out:
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# Best hyperparameters: {'n_estimators': 200, 'min_child_weight': 1, 'max_depth': 5, 'learning_rate': 0.15, 'gamma': 0}
# Best mean cross-validation score: 87.2860%
# Test set accuracy: 95.0775%

# %%
import numpy as np
import pandas as pd
import xgboost as xgb
from sklearn.model_selection import StratifiedKFold, RandomizedSearchCV
from sklearn.metrics import accuracy_score, make_scorer
from imblearn.over_sampling import SMOTE

# Load the dataset
df =data.copy()

# Split the dataset into features and target variable
X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values

# Resample the data to address class imbalance using SMOTE
sm = SMOTE(random_state=42)
X_resampled, y_resampled = sm.fit_resample(X, y)

# Create the stratified 10-fold cross-validator
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

# Define the hyperparameter grid for the XGBoost model
param_grid = {'max_depth': [3, 4, 5],
              'learning_rate': [0.05, 0.1, 0.15],
              'n_estimators': [100, 200, 300],
              'min_child_weight': [1, 3, 5],
              'gamma': [0, 0.1, 0.2]}

# Create the XGBoost classifier
xgb_classifier = xgb.XGBClassifier(objective='binary:logistic', random_state=42)

# Define the scoring metric for the randomized search
scoring_metric = make_scorer(accuracy_score)

# Create the randomized search object
random_search = RandomizedSearchCV(xgb_classifier, param_grid, n_iter=50, cv=skf, scoring=scoring_metric,
                                   random_state=42, verbose=1, n_jobs=-1)

# Fit the randomized search object to the resampled data
random_search.fit(X_resampled, y_resampled)

print(f"Best hyperparameters: {random_search.best_params_}")

# Use the best model to make predictions on the original dataset
best_model = random_search.best_estimator_
accuracy_scores = best_model.predict_proba(X)[:,1]

# Convert the accuracy scores to percentages and round to two decimal places
accuracy_percents = np.round(accuracy_scores * 100, 2)

# Add a new column 'accuracy' to the original dataset
df['Level'] = accuracy_percents

# Add a new column 'abnormality_level' based on the accuracy score
df['Abnormality_Level'] = pd.cut(df['Level'], bins=[0, 40, 70, 100], labels=['Low', 'Medium', 'High'])

# Filter the dataset to include only rows with target=1
df_filtered = df.loc[df['T'] == 1, df.columns != 'T']
# Out:
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# Best hyperparameters: {'n_estimators': 200, 'min_child_weight': 1, 'max_depth': 5, 'learning_rate': 0.15, 'gamma': 0}

# %%
df_filtered
# Out:
#       Age  DM   TG  HT   HDL     AC      Level Abnormality_Level
# 2741   73   1  187   0  39.0   95.0  62.439999            Medium
# 2742   58   1   80   0  41.0   94.0  39.230000               Low
# 2743   62   1   88   1  65.0   82.0  54.740002            Medium
# 2744   56   1  196   1  43.0  104.0  30.290001               Low
# 2745   75   0  104   1  41.0  112.0  60.029999            Medium
# ...   ...  ..  ...  ..   ...    ...        ...               ...
# 3392   67   1   87   1  43.0  108.0  50.470001            Medium
# 3393   77   0   65   1  37.0  104.0  57.060001            Medium
# 3394   74   1  707   1  30.0  117.0  98.580002              High
# 3395   61   1  164   1  54.0   99.0  39.299999               Low
# 3396   46   1  178   0  34.0  114.0  66.260002            Medium
#
# [656 rows x 8 columns]
